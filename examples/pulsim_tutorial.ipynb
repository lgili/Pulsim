# %% [markdown]
# # Pulsim Tutorial
#
# This notebook demonstrates how to use Pulsim for circuit simulation, focusing on power electronics applications.
#
# It uses the **v2 API**: build a circuit with `p.CircuitBuilder()` using string node
# names, then call the free functions `p.compute_dc_op(...)` and `p.simulate(...)`.
# Switching converters are driven by a `p.MixedDomainBlockChain` (PWM / PI blocks)
# instead of the old `SignalEvaluator` + closures. See `docs/migration-from-v1.md`
# for the full v1 → v2 mapping.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pulsim as p

print(f"Pulsim version: {p.__version__}")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# ...

# %% [markdown]
# ## 1. Simple RC Circuit
#
# Let's start with a basic RC circuit to understand the API.

# %%
# Create a simple RC circuit (v2: CircuitBuilder + string node names)
circuit = p.CircuitBuilder()

# "gnd" is the ground reference — no add_node / ground() needed.
circuit.add_voltage_source('V1', 'in', 'gnd', 5.0)
circuit.add_resistor('R1', 'in', 'out', 1000.0)
circuit.add_capacitor('C1', 'out', 'gnd', 1e-6)

# Validate the circuit
print(f"Nodes: {circuit.graph.num_nodes}")
# Out:
# Nodes: 2

# %%
# Run transient simulation (v2: one free-function call, fixed dt)
res = p.simulate(circuit, t_end=5e-3, dt=1e-6)

times = np.array(res.times)
states = np.array(res.states)   # shape (N+1, system_size)

print(f"Total steps: {len(times)}")
print(f"System size: {states.shape[1]}")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Total steps: 5001
# System size: 3

# %%
# Plot results — extract node voltages by name with b.node_id_of(...)
fig, ax = plt.subplots(figsize=(10, 5))

time_ms = times * 1000
v_in = states[:, circuit.node_id_of('in')]
v_out = states[:, circuit.node_id_of('out')]

ax.plot(time_ms, v_in, label='V(in)', linewidth=2)
ax.plot(time_ms, v_out, label='V(out)', linewidth=2)

# Add theoretical curve
tau = 1e-3
v_theory = 5.0 * (1 - np.exp(-times / tau))
ax.plot(time_ms, v_theory, '--', label='Theoretical', alpha=0.7)

ax.set_xlabel('Time (ms)')
ax.set_ylabel('Voltage (V)')
ax.set_title('RC Circuit Step Response')
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Buck Converter Simulation
#
# Now let's simulate a more interesting circuit: a buck converter for power electronics.
#
# In v2 the power stage is **pure topology** (a high-side switch + a free-wheeling
# diode + the LC filter). The PWM gate is generated by a `p.MixedDomainBlockChain`
# and applied to the switch via `chain.make_pwm_switch_fn(...)`. Here we run
# **open loop** at a fixed duty of 0.5, so the output settles near `D · Vin = 24 V`.

# %%
# Buck converter power stage (v2 topology only).
#
#   Vdc=48V --[S1]-- sw --[L1]-- out --+-- Rload --gnd
#                     |                |
#                  [D1 fw]           [C1]
#                     |                |
#                    gnd              gnd
#
# S1 is an ideal high-side switch (g_on/g_off are conductances). D1 is the
# free-wheeling diode that carries the inductor current while S1 is off.

F_SW = 20e3      # PWM switching frequency [Hz]
DUTY = 0.5       # fixed duty (open loop)
VIN = 48.0

buck = p.CircuitBuilder()
buck.add_voltage_source('Vdc', 'vcc', 'gnd', VIN)
buck.add_switch('S1', 'vcc', 'sw', g_on=1.0 / 0.01, g_off=1.0 / 1e9)
buck.add_diode('D1', 'gnd', 'sw', g_on=100.0, g_off=1e-9, V_th=0.0)
buck.add_inductor('L1', 'sw', 'out', 100e-6)
buck.add_capacitor('C1', 'out', 'gnd', 100e-6)
buck.add_resistor('Rload', 'out', 'gnd', 10.0)

print(f"Nodes: {buck.graph.num_nodes}, switches: {buck.graph.num_switches}")

# Control chain: a PWM generator producing the gate signal for S1.
chain = p.MixedDomainBlockChain()
chain.add('pwm', p.PwmGenerator(frequency=F_SW),
          inputs=dict(duty=DUTY, t='time'), output='gate')
# Out:
# Nodes: 3, switches: 2

# %%
# Simulate buck converter. dt = 50 samples per PWM period.
DT = 1.0 / F_SW / 50

observer = chain.make_step_observer(buck, dt=DT)
switch_fn = chain.make_pwm_switch_fn('gate',
                                     num_switches=buck.graph.num_switches,
                                     switch_idx=0)

result = p.simulate(buck, t_end=2e-3, dt=DT,
                    switch_fn=switch_fn, step_observer=observer)

times = np.array(result.times)
states = np.array(result.states)
print(f"Steps: {len(times)}")
# Out:
# Steps: 2001

# %%
# Plot buck converter waveforms.
# v2 result accessors: res.v(node) for voltages, res.i(device) for currents.
fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

time_us = times * 1e6
v_sw = np.array(result.v('sw'))
v_out = np.array(result.v('out'))
i_L = np.array(result.i('L1'))

# Plot 1: switch node voltage (chops between ~0 and Vin)
ax1 = axes[0]
ax1.plot(time_us, v_sw, label='V(sw)', alpha=0.8)
ax1.axhline(VIN, color='k', ls='--', lw=0.5, alpha=0.5, label=f'Vin = {VIN:.0f}V')
ax1.set_ylabel('Voltage (V)')
ax1.set_title('Buck Converter: Switch Node')
ax1.legend(loc='upper right')
ax1.grid(True, alpha=0.3)

# Plot 2: Output voltage
ax2 = axes[1]
ax2.plot(time_us, v_out, label='V(out)', color='green', linewidth=1.5)
ax2.axhline(y=VIN * DUTY, color='red', linestyle='--', alpha=0.5,
            label=f'Target (D·Vin = {VIN*DUTY:.0f}V)')
ax2.set_ylabel('Voltage (V)')
ax2.set_title(f"Output Voltage (final: {v_out[-1]:.2f}V)")
ax2.legend(loc='lower right')
ax2.grid(True, alpha=0.3)

# Plot 3: Inductor current
ax3 = axes[2]
ax3.plot(time_us, i_L, label='I(L1)', color='orange', linewidth=1.5)
ax3.set_xlabel('Time (us)')
ax3.set_ylabel('Current (A)')
ax3.set_title(f"Inductor Current (final: {i_L[-1]:.2f}A)")
ax3.legend(loc='lower right')
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Per-resistor average dissipated power is available via res.power(name).
# (For a full conduction + switching loss breakdown per switch/diode over a
#  run, see p.LossAccumulator / p.device_loss_summary.)
print(f"Average power delivered to Rload: {result.power('Rload'):.2f} W")
# Out:
# Average power delivered to Rload: 90.34 W

# %% [markdown]
# ## 3. Zoom into Switching Waveforms
#
# Let's look at a few switching cycles in detail.

# %%
# Zoom into last few cycles
fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

# Find indices for last 200us
mask = times > (times[-1] - 200e-6)
time_zoom = times[mask] * 1e6

v_sw = np.array(result.v('sw'))
i_L = np.array(result.i('L1'))

ax1 = axes[0]
ax1.plot(time_zoom, v_sw[mask], label='V(sw)', linewidth=1.5)
ax1.set_ylabel('Voltage (V)')
ax1.set_title('Switch Node Voltage (Zoomed)')
ax1.grid(True, alpha=0.3)
ax1.legend()

ax2 = axes[1]
ax2.plot(time_zoom, i_L[mask], label='I(L1)', color='orange', linewidth=1.5)
ax2.set_xlabel('Time (us)')
ax2.set_ylabel('Current (A)')
ax2.set_title('Inductor Current Ripple')
ax2.grid(True, alpha=0.3)
ax2.legend()

# Calculate ripple
i_ripple = i_L[mask].max() - i_L[mask].min()
print(f"Inductor current ripple: {i_ripple:.3f} A peak-to-peak")

plt.tight_layout()
plt.show()
# Out:
# Inductor current ripple: 5.535 A peak-to-peak

# %% [markdown]
# ## 4. Pulsed-Source RLC Circuit
#
# A series RLC driven by a pulse source. This shows the `add_pulse_voltage_source`
# helper and the underdamped step response of an RLC tank.

# %%
# Build a series RLC circuit driven by a pulse source.
#   V1(pulse) -- in --[R1]-- n1 --[L1]-- out --[C1]-- gnd
rlc = p.CircuitBuilder()

# add_pulse_voltage_source(name, n_pos, n_neg, v_initial, v_pulsed,
#                          t_start, pulse_width, period, rise_time, fall_time)
rlc.add_pulse_voltage_source('V1', 'in', 'gnd',
                             0.0, 1.0, 0.0, 1e-3,
                             period=2e-3, rise_time=1e-9, fall_time=1e-9)
rlc.add_resistor('R1', 'in', 'n1', 10.0)
rlc.add_inductor('L1', 'n1', 'out', 100e-6)
rlc.add_capacitor('C1', 'out', 'gnd', 10e-9)

print(f"Circuit: {rlc.graph.num_nodes} nodes")

# Simulate
res = p.simulate(rlc, t_end=500e-6, dt=10e-9)
times = np.array(res.times)

# Plot
fig, ax = plt.subplots(figsize=(10, 5))
time_us = times * 1e6
ax.plot(time_us, np.array(res.v('out')), label='V(out)')
ax.set_xlabel('Time (us)')
ax.set_ylabel('Voltage (V)')
ax.set_title('RLC Circuit Response')
ax.grid(True, alpha=0.3)
ax.legend()
plt.tight_layout()
plt.show()

# Calculate resonant frequency
L = 100e-6
C = 10e-9
f0 = 1 / (2 * np.pi * np.sqrt(L * C))
print(f"Theoretical resonant frequency: {f0/1000:.1f} kHz")
# Out:
# Circuit: 3 nodes
# Theoretical resonant frequency: 159.2 kHz

# %% [markdown]
# ## 5. Thermal Simulation
#
# Pulsim v2 models device self-heating with a **Foster RC ladder**. Given a
# per-stage `(R_th, τ)` list and a power-loss waveform `P(t)`, the helper
# `p.compute_temperature(t, P, stages, T_amb_C)` convolves `P(t)` with the
# thermal impedance `Z_th(t)` to return the junction temperature `T_j(t)`.
#
# (The v1 `create_mosfet_thermal_model` / `ThermalSimulator` step-loop API was
# removed in v2 — see `docs/migration-from-v1.md` § 6.)

# %%
# Foster thermal model for a MOSFET (3 stages: junction-case, case-sink,
# sink-ambient). FosterStage(R_th [K/W], tau [s]).
thermal_stages = [
    p.FosterStage(R_th_K_per_W=0.5, tau_s=0.05),   # junction-to-case (fast)
    p.FosterStage(R_th_K_per_W=0.3, tau_s=0.5),    # case-to-sink
    p.FosterStage(R_th_K_per_W=2.0, tau_s=5.0),    # sink-to-ambient (slow)
]

R_th_total = sum(s.R_th_K_per_W for s in thermal_stages)
print(f"Total Rth (junction to ambient): {R_th_total:.2f} K/W")
print(f"Foster network stages: {len(thermal_stages)}")
# Out:
# Total Rth (junction to ambient): 2.80 K/W
# Foster network stages: 3

# %%
# Simulate thermal response to a constant 10 W dissipation.
power = 10.0    # 10 W
dt = 1e-3       # 1 ms timestep
t_total = 5.0   # 5 s

t_therm = np.arange(0.0, t_total, dt)
p_loss = np.full_like(t_therm, power)

# Convolve P(t) with Z_th(t) → T_j(t)  (ambient = 25 °C)
T_amb = 25.0
temps = p.compute_temperature(t_therm, p_loss, thermal_stages, T_amb_C=T_amb)

# Plot thermal response
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(t_therm, temps, linewidth=2)

# Theoretical steady-state
t_ss = T_amb + power * R_th_total
ax.axhline(y=t_ss, color='red', linestyle='--', alpha=0.7,
           label=f"Steady-state: {t_ss:.1f}°C")

ax.set_xlabel("Time (s)")
ax.set_ylabel("Junction Temperature (°C)")
ax.set_title(f"MOSFET Thermal Response (P = {power}W)")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Final junction temperature: {temps[-1]:.1f}°C")
# Out:
# Final junction temperature: 45.6°C

# %% [markdown]
# ## 6. Exporting Results
#
# Simulation results can be easily exported for further analysis.

# %%
# Build a results dictionary for export (uses the RLC sim from section 4).
data = {
    'time': np.array(res.times),
    'signals': {
        'V(in)': np.array(res.v('in')),
        'V(n1)': np.array(res.v('n1')),
        'V(out)': np.array(res.v('out')),
        'I(L1)': np.array(res.i('L1')),
    },
}

print('Result dictionary keys:', list(data.keys()))
print(f"Number of time points: {len(data['time'])}")
print(f"Signals available: {list(data['signals'].keys())}")
# Out:
# Result dictionary keys: ['time', 'signals']
# Number of time points: 50001
# Signals available: ['V(in)', 'V(n1)', 'V(out)', 'I(L1)']

# %%
# Example: Create a pandas DataFrame
try:
    import pandas as pd

    df = pd.DataFrame({
        'time': data['time'],
        **data['signals'],
    })

    print(df.head())
    print(f"\nDataFrame shape: {df.shape}")

    # Could save to CSV:
    # df.to_csv('simulation_results.csv', index=False)
except ImportError:
    print('pandas not installed - skipping DataFrame example')
# Out:
#            time  V(in)     V(n1)    V(out)     I(L1)
# 0  0.000000e+00    0.0  0.000000  0.000000  0.000000
# 1  1.000000e-08    1.0  0.999500  0.000025  0.000050
# 2  2.000000e-08    1.0  0.998501  0.000125  0.000150
# 3  3.000000e-08    1.0  0.997504  0.000325  0.000250
# 4  4.000000e-08    1.0  0.996507  0.000624  0.000349
#
# DataFrame shape: (50001, 5)

# %% [markdown]
# ## Summary
#
# This tutorial covered:
#
# 1. **Basic circuit construction** — building circuits with `p.CircuitBuilder()` and string node names (resistors, capacitors, inductors, sources)
# 2. **Transient simulation** — `p.simulate(b, t_end=…, dt=…)`, reading results via `res.v(node)` / `res.i(device)`
# 3. **Power electronics** — an open-loop buck driven by a `p.MixedDomainBlockChain` (PWM gate → `make_pwm_switch_fn`)
# 4. **Pulsed sources** — `add_pulse_voltage_source` exciting a series RLC tank
# 5. **Thermal modeling** — Foster ladder + `p.compute_temperature(...)`
#
# ### Key API
#
# ```python
# import pulsim as p
#
# b = p.CircuitBuilder()
# b.add_resistor("R1", "n1", "n2", 1e3)
# b.add_switch("S1", "a", "b", g_on=1e3, g_off=1e-9)
# dc  = p.compute_dc_op(b)            # DC operating point (vector)
# res = p.simulate(b, t_end=…, dt=…)  # transient
# v   = res.v("n2")                    # node voltage trace
# i   = res.i("L1")                    # device current trace
# ```
