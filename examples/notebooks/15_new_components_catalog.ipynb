# %% [markdown]
# # 15 - Catalogo de componentes (YAML v2)
#
# Este notebook valida o carregamento de **todos os tipos de dispositivo**
# suportados pelo loader YAML v2 (`p.load_yaml_string` / `p.load_yaml_file`).
#
# Objetivo:
# - mostrar o YAML minimo de cada dispositivo no schema v2 (`circuit:` ->
#   `devices:`);
# - validar que o loader constroi o `CircuitBuilder` sem erro;
# - conferir a contagem de nos/branches por caso.

# %% [markdown]
# > **Mudanca v1 -> v2 (migration-from-v1.md secao 7).** O loader YAML
# > v1 (`schema: pulsim-v1` + `ps.YamlParser`) aceitava ~52 tipos,
# > incluindo *virtual components* de GUI: blocos de controle
# > (`PI_CONTROLLER`, `PWM_GENERATOR`, `COMPARATOR`, ...), instrumentacao
# > (`VOLTAGE_PROBE`, `ELECTRICAL_SCOPE`, ...), protecao (`FUSE`, `RELAY`,
# > `THYRISTOR`, `TRIAC`) e `BJT`/`COUPLED_INDUCTOR`/`SNUBBER_RC`.
# >
# > O loader v2 expoe **~20 device kinds** (a topologia pura). O que saiu
# > do catalogo YAML foi **realocado**, nao removido:
# > - **Blocos de controle** vivem agora na `MixedDomainBlockChain`
# >   (`p.PIController`, `p.PwmGenerator`, ...), nao no device pool — veja
# >   `16_control_blocks_mixed_domain.ipynb`.
# > - **Snubber RC** -> helper `p.add_rc_snubber(b, ...)`.
# > - **Coupled inductor** -> `b.add_transformer(...)`.
# > - **Probes / scopes** -> leia o vetor de estado direto
# >   (`res.states[:, b.node_id_of(...)]`) ou registre canais da chain.
# > - **Fuse / breaker / relay / thyristor / triac / BJT** ainda nao tem
# >   device kind v2 (gap deliberado; abra issue se precisar).
# >
# > Este notebook valida o catalogo YAML **v2 real**.

# %%
import pulsim as p
import numpy as np
import matplotlib.pyplot as plt

print(f"Pulsim version: {p.__version__}")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# ...

# %% [markdown]
# ## 1. Snippets YAML v2 — um por device kind
#
# Cada entrada e um mapa plano `{type, name, <nos>, <params>}`. Nos sao
# **strings**; `gnd` e a referencia de terra. Os snippets abaixo sao
# concatenados a uma fonte + resistor de base para formar um circuito
# valido.

# %%
# One minimal valid entry per v2 YAML device kind.
DEVICE_SNIPPETS = {
    "resistor":               {"type": "resistor", "name": "R1", "from": "a", "to": "gnd", "R": 1000},
    "capacitor":              {"type": "capacitor", "name": "C1", "from": "a", "to": "gnd", "C": 1e-6},
    "inductor":               {"type": "inductor", "name": "L1", "from": "a", "to": "gnd", "L": 1e-3},
    "saturable_inductor":     {"type": "saturable_inductor", "name": "Lsat", "from": "a", "to": "gnd", "L_0": 1e-3, "I_sat": 2.0},
    "hysteretic_inductor":    {"type": "hysteretic_inductor", "name": "Lh", "from": "a", "to": "gnd", "N_turns": 50, "l_m": 0.1, "A_core": 1e-4},
    "transformer":            {"type": "transformer", "name": "T1", "p_from": "a", "p_to": "gnd", "s_from": "sec", "s_to": "gnd", "L_p": 1e-3, "L_s": 2e-3, "k": 0.95},
    "current_source":         {"type": "current_source", "name": "I1", "from": "a", "to": "gnd", "I": 0.01},
    "sine_voltage_source":    {"type": "sine_voltage_source", "name": "VS", "from": "a", "to": "gnd", "v_amplitude": 5, "frequency": 60},
    "pulse_voltage_source":   {"type": "pulse_voltage_source", "name": "VP", "from": "a", "to": "gnd", "v_initial": 0, "v_pulsed": 5, "period": 1e-3, "pulse_width": 5e-4, "rise_time": 1e-6, "fall_time": 1e-6},
    "pwm_voltage_source":     {"type": "pwm_voltage_source", "name": "VW", "from": "a", "to": "gnd", "v_high": 5, "v_low": 0, "frequency": 1e3, "duty": 0.5},
    "switch":                 {"type": "switch", "name": "S1", "from": "a", "to": "gnd", "g_on": 1e3, "g_off": 1e-9},
    "diode":                  {"type": "diode", "name": "D1", "anode": "a", "cathode": "gnd", "g_on": 1e3, "g_off": 1e-9},
    "nonlinear_diode":        {"type": "nonlinear_diode", "name": "Dn", "anode": "a", "cathode": "gnd"},
    "mosfet":                 {"type": "mosfet", "name": "M1", "drain": "a", "source": "gnd", "gate": "g"},
    "mosfet_with_body_diode": {"type": "mosfet_with_body_diode", "name": "Mb", "drain": "a", "source": "gnd", "gate": "g"},
    "mosfet_level1":          {"type": "mosfet_level1", "name": "Ml", "drain": "a", "source": "gnd", "gate": "g", "K": 0.35, "V_T": 3.0},
    "igbt":                   {"type": "igbt", "name": "Q1", "collector": "a", "emitter": "gnd", "gate": "g"},
    "igbt_level1":            {"type": "igbt_level1", "name": "Ql", "collector": "a", "emitter": "gnd", "gate": "g"},
    "op_amp_ideal":           {"type": "op_amp_ideal", "name": "A1", "in_pos": "a", "in_neg": "b", "out": "o"},
    "vcvs":                   {"type": "vcvs", "name": "E1", "in_pos": "a", "in_neg": "b", "out_pos": "o", "out_neg": "gnd", "gain": 10},
}

print(f"Device kinds no catalogo YAML v2: {len(DEVICE_SNIPPETS)}")
# Out:
# Device kinds no catalogo YAML v2: 20

# %%
def _flow(d):
    """Render a flat dict as a YAML flow-style mapping."""
    return "{" + ", ".join(f"{k}: {v}" for k, v in d.items()) + "}"


def build_yaml_case(entry: dict) -> str:
    """Wrap one device entry in a minimal valid v2 circuit."""
    source = {"type": "voltage_source", "name": "Vsrc", "from": "a", "to": "gnd", "V": 5}
    pull = {"type": "resistor", "name": "Rpull", "from": "a", "to": "gnd", "R": 1e9}
    lines = ["circuit:", "  devices:",
             f"  - {_flow(source)}",
             f"  - {_flow(entry)}",
             f"  - {_flow(pull)}"]
    return "\n".join(lines) + "\n"


# Show one fully-rendered example so the schema is concrete.
print(build_yaml_case(DEVICE_SNIPPETS["mosfet_with_body_diode"]))
# Out:
# circuit:
#   devices:
#   - {type: voltage_source, name: Vsrc, from: a, to: gnd, V: 5}
#   - {type: mosfet_with_body_diode, name: Mb, drain: a, source: gnd, gate: g}
#   - {type: resistor, name: Rpull, from: a, to: gnd, R: 1000000000.0}

# %% [markdown]
# ## 2. Validar o catalogo
#
# Para cada device kind: monta o YAML, chama `p.load_yaml_string`, e
# confere que o `CircuitBuilder` resultante tem nos/branches.

# %%
rows = []
for kind, entry in DEVICE_SNIPPETS.items():
    try:
        loaded = p.load_yaml_string(build_yaml_case(entry))
        b = loaded.builder
        rows.append({
            "device": kind,
            "status": "OK",
            "nodes": b.graph.num_nodes,
            "branches": b.graph.num_branches,
            "error": "",
        })
    except Exception as exc:  # noqa: BLE001 — we want to report, not crash
        rows.append({
            "device": kind, "status": "ERRO", "nodes": 0, "branches": 0,
            "error": str(exc).splitlines()[-1][:80],
        })

print(f"{'DEVICE':<24} {'STATUS':<8} {'NODES':>6} {'BRANCHES':>9}")
print("-" * 52)
for row in rows:
    print(f"{row['device']:<24} {row['status']:<8} {row['nodes']:>6} {row['branches']:>9}")

failed = [r for r in rows if r["status"] != "OK"]
print(f"\nTotal OK: {len(rows) - len(failed)} / {len(rows)}")
if failed:
    print("\nFalhas:")
    for r in failed:
        print(f"- {r['device']}: {r['error']}")

assert not failed, "Um ou mais device kinds nao foram carregados."
# Out:
# DEVICE                   STATUS    NODES  BRANCHES
# ----------------------------------------------------
# resistor                 OK            1         3
# capacitor                OK            1         3
# inductor                 OK            1         3
# saturable_inductor       OK            1         3
# hysteretic_inductor      OK            2         4
# transformer              OK            2         4
# current_source           OK            1         3
# sine_voltage_source      OK            1         3
# pulse_voltage_source     OK            1         3
# pwm_voltage_source       OK            1         3
# switch                   OK            1         3
# diode                    OK            1         3
# nonlinear_diode          OK            1         3
# mosfet                   OK            1         3
# mosfet_with_body_diode   OK            1         4
# mosfet_level1            OK            2         3
# ...

# %% [markdown]
# ## 3. Onde foram parar os *virtual components* do v1
#
# Os blocos que sairam do catalogo YAML foram realocados para a API
# Python. As celulas abaixo provam que os equivalentes existem e rodam.

# %%
# 3a. Blocos de controle -> MixedDomainBlockChain (control.py).
control_blocks = {
    "PI_CONTROLLER":     "PIController",
    "PID_CONTROLLER":    "PIDController",
    "COMPARATOR":        "Comparator",
    "MATH_BLOCK":        "MathBlock",
    "PWM_GENERATOR":     "PwmGenerator",
    "INTEGRATOR":        "Integrator",
    "DIFFERENTIATOR":    "Differentiator",
    "LIMITER":           "Limiter",
    "RATE_LIMITER":      "RateLimiter",
    "HYSTERESIS":        "Comparator (hysteresis=...)",
    "LOOKUP_TABLE":      "LookupTable1D",
    "TRANSFER_FUNCTION": "TransferFunction",
    "DELAY_BLOCK":       "DelayBlock",
    "SAMPLE_HOLD":       "SampleHold",
    "STATE_MACHINE":     "StateMachine",
    "SIGNAL_MUX":        "SignalMux",
    "SIGNAL_DEMUX":      "SignalDemux",
    "OP_AMP":            "OpAmp / add_op_amp_ideal",
}
print("v1 YAML virtual block -> v2 chain block\n")
for v1_kind, v2_block in control_blocks.items():
    first = v2_block.split()[0].split('/')[0].strip()
    ok = "OK" if hasattr(p, first) else "MISSING"
    print(f"  {v1_kind:<20} -> p.{v2_block:<28} ({ok})")
# Out:
# v1 YAML virtual block -> v2 chain block
#
#   PI_CONTROLLER        -> p.PIController                 (OK)
#   PID_CONTROLLER       -> p.PIDController                (OK)
#   COMPARATOR           -> p.Comparator                   (OK)
#   MATH_BLOCK           -> p.MathBlock                    (OK)
#   PWM_GENERATOR        -> p.PwmGenerator                 (OK)
#   INTEGRATOR           -> p.Integrator                   (OK)
#   DIFFERENTIATOR       -> p.Differentiator               (OK)
#   LIMITER              -> p.Limiter                      (OK)
#   RATE_LIMITER         -> p.RateLimiter                  (OK)
#   HYSTERESIS           -> p.Comparator (hysteresis=...)  (OK)
#   LOOKUP_TABLE         -> p.LookupTable1D                (OK)
#   TRANSFER_FUNCTION    -> p.TransferFunction             (OK)
#   DELAY_BLOCK          -> p.DelayBlock                   (OK)
#   SAMPLE_HOLD          -> p.SampleHold                   (OK)
# ...

# %%
# 3b. Snubber RC e coupled inductor -> helpers de builder.
b = p.CircuitBuilder()
b.add_voltage_source("V1", "in", "gnd", 18.0)
b.add_resistor("Rload", "out", "gnd", 2.5)
# coupled inductor == transformer (Lp, Ls, k)
b.add_transformer("K1", "in", "out", "sec", "gnd", L_p=1e-3, L_s=2e-3, k=0.95)
b.add_resistor("Rsec", "sec", "gnd", 4.0)
# snubber RC across the load
p.add_rc_snubber(b, R=120.0, C=100e-9, from_node="out", to_node="gnd", name_prefix="SN1")

res = p.simulate(b, t_end=2e-3, dt=2e-5)
vout = np.array(res.states)[:, b.node_id_of("out")]
print("Snubber + coupled-inductor (transformer) circuit built and simulated:")
print(f"  nodes={b.graph.num_nodes}, branches={b.graph.num_branches}")
print(f"  V(out) final = {vout[-1]:.3f} V")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Snubber + coupled-inductor (transformer) circuit built and simulated:
#   nodes=4, branches=7
#   V(out) final = 17.177 V

# %%
# 3c. Probes / scopes -> leitura direta do vetor de estado.
rc = p.CircuitBuilder()
rc.add_voltage_source("V1", "in", "gnd", 5.0)
rc.add_resistor("R1", "in", "out", 1000.0)
rc.add_capacitor("C1", "out", "gnd", 1e-6)
res = p.simulate(rc, t_end=5e-3, dt=5e-5)
states = np.array(res.states)

# 'VOLTAGE_PROBE' on 'out' is just a column of the state matrix:
v_probe = states[:, rc.node_id_of("out")]
# source-branch current ('CURRENT_PROBE' on V1) is also a state var:
i_src = states[:, rc.state_var_names().index("Is(V1)")]
print(f"VOLTAGE_PROBE(out): final = {v_probe[-1]:.4f} V")
print(f"CURRENT_PROBE(V1):  final = {i_src[-1] * 1e3:.4f} mA")
print(f"State variables exposed: {rc.state_var_names()}")
# Out:
# VOLTAGE_PROBE(out): final = 4.9655 V
# CURRENT_PROBE(V1):  final = -0.0345 mA
# State variables exposed: ['V(in)', 'V(out)', 'Is(V1)']

# %% [markdown]
# ## Resultado esperado
#
# - A celula de validacao (secao 2) termina com `Total OK: 20 / 20`.
# - Todos os blocos de controle do v1 tem um equivalente na
#   `MixedDomainBlockChain` (secao 3a).
# - Snubber, coupled-inductor e probes do v1 sao reproduzidos por
#   helpers v2 / leitura de estado (secoes 3b, 3c).
#
# Para os blocos de controle em acao, veja
# `16_control_blocks_mixed_domain.ipynb`.
