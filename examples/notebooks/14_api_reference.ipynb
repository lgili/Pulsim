# %% [markdown]
# # Pulsim v2 API Reference
#
# A tour of the **v2 public API surface**. v2 replaces v1's monolithic
# `RuntimeCircuit` with focused, composable pieces:
#
# 1. `CircuitBuilder` — pure topology (devices + nodes by name)
# 2. `compute_dc_op(b)` — DC operating point as a free function
# 3. `simulate(b, ...)` — transient analysis as a free function
# 4. `run_ac_sweep(b, ...)` — small-signal AC sweep
# 5. `MixedDomainBlockChain` — control / signal-flow blocks
# 6. Analytical references for validation
#
# Every analysis takes the `builder` as the **first argument** instead of
# being a method on a circuit object. See `docs/migration-from-v1.md` for
# the full v1 -> v2 mapping.

# %%
import pulsim as p
import numpy as np
import matplotlib.pyplot as plt

print(f"Pulsim version: {p.__version__}")
print(f"Public symbols: {len([s for s in dir(p) if not s.startswith('_')])}")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# ...

# %% [markdown]
# ## 1. Building a circuit
#
# `CircuitBuilder` is the v2 entry point. Nodes are **strings** (`"gnd"` is
# the implicit ground reference) - no `add_node` / `ground()` bookkeeping.
# Each `add_*` returns the builder so calls can be chained.

# %%
b = p.CircuitBuilder()
b.add_voltage_source("Vdc", "vin", "gnd", 12.0)   # name, from, to, V
b.add_resistor("R1", "vin", "vout", 1000.0)        # name, from, to, R
b.add_capacitor("C1", "vout", "gnd", 1e-6)          # name, from, to, C
b.add_inductor("L1", "vout", "gnd", 1e-3)           # name, from, to, L

print("Topology:")
print(f"  Nodes:    {b.graph.num_nodes}")
print(f"  Branches: {b.graph.num_branches}")
print(f"  Switches: {b.graph.num_switches}")
print(f"  node_id_of('vout') = {b.node_id_of('vout')}")
print(f"  state vars: {b.state_var_names()}")
# Out:
# Topology:
#   Nodes:    2
#   Branches: 4
#   Switches: 0
#   node_id_of('vout') = 1
#   state vars: ['V(vin)', 'V(vout)', 'Is(Vdc)', 'I(L1)']

# %% [markdown]
# ## 2. Device library on `CircuitBuilder`
#
# The builder exposes every primitive device as an `add_*` method.
# Power-stage and three-phase helpers are **free functions** that take the
# builder as their first argument.

# %%
builder_methods = sorted(m for m in dir(p.CircuitBuilder)
                          if m.startswith("add_"))
print("CircuitBuilder.add_* methods:")
for m in builder_methods:
    print(f"  b.{m}(...)")

free_helpers = sorted(s for s in dir(p)
                       if s.startswith("add_") and s not in builder_methods)
print("\nFree-function helpers (first arg = builder):")
for s in free_helpers:
    print(f"  p.{s}(b, ...)")
# Out:
# CircuitBuilder.add_* methods:
#   b.add_capacitor(...)
#   b.add_current_source(...)
#   b.add_diode(...)
#   b.add_igbt(...)
#   b.add_igbt_level1(...)
#   b.add_inductor(...)
#   b.add_mosfet(...)
#   b.add_mosfet_level1(...)
#   b.add_mosfet_with_body_diode(...)
#   b.add_nonlinear_diode(...)
#   b.add_op_amp_ideal(...)
#   b.add_pulse_voltage_source(...)
#   b.add_pwm_voltage_source(...)
#   b.add_resistor(...)
#   b.add_saturable_inductor(...)
#   b.add_sine_voltage_source(...)
#   b.add_switch(...)
#   b.add_transformer(...)
#   b.add_vcvs(...)
#   b.add_voltage_source(...)
#
# Free-function helpers (first arg = builder):
#   p.add_bldc(b, ...)
#   p.add_boost(b, ...)
#   p.add_bridge_rectifier(b, ...)
#   p.add_buck(b, ...)
#   p.add_dc_motor(b, ...)
#   p.add_flyback(b, ...)
#   p.add_foster_network(b, ...)
#   p.add_hysteretic_inductor(b, ...)
#   p.add_induction_motor(b, ...)
#   p.add_mmc_arm_average(b, ...)
#   p.add_mmc_arm_detailed(b, ...)
# ...

# %% [markdown]
# ## 3. DC operating point
#
# `compute_dc_op(b)` returns the solution **vector**; index it by node
# name via `b.node_id_of(...)`. The strategy defaults to `"auto"`, which
# picks Gmin-stepping / source-stepping / pseudo-transient as needed for
# hard operating points.

# %%
dc = p.compute_dc_op(b)

print("DC operating point:")
print(f"  V(vin)  = {dc[b.node_id_of('vin')]:.4f} V")
print(f"  V(vout) = {dc[b.node_id_of('vout')]:.4f} V")
print()
print("At DC the capacitor is open and the inductor is a short to gnd,")
print("so V(vout) is pulled to 0 V through L1.")
# Out:
# DC operating point:
#   V(vin)  = 12.0000 V
#   V(vout) = 0.0000 V
#
# At DC the capacitor is open and the inductor is a short to gnd,
# so V(vout) is pulled to 0 V through L1.

# %% [markdown]
# ## 4. Transient simulation
#
# `simulate(b, t_end=, dt=)` is the single entry point for transient runs.
# It returns a `SimulationResult` dataclass with `times`, `states`
# (shape `(N+1, system_size)`), plus convenience views. The integrator is
# chosen automatically (`'auto'`): BDF1 for stiff/slow plants, trapezoidal
# otherwise.

# %%
# A clean RC step response (drop the inductor so vout settles to Vdc).
rc = p.CircuitBuilder()
rc.add_voltage_source("Vdc", "vin", "gnd", 5.0)
rc.add_resistor("R1", "vin", "vout", 1000.0)
rc.add_capacitor("C1", "vout", "gnd", 1e-6)
tau = 1000.0 * 1e-6

res = p.simulate(rc, t_end=5 * tau, dt=tau / 100)
times = np.array(res.times)
states = np.array(res.states)

print("SimulationResult:")
print(f"  type:         {type(res).__name__}")
print(f"  num_steps():  {res.num_steps()}")
print(f"  times shape:  {times.shape}")
print(f"  states shape: {states.shape}  (N+1, system_size)")
print(f"  V(vout) final: {states[-1, rc.node_id_of('vout')]:.4f} V")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# SimulationResult:
#   type:         SimulationResult
#   num_steps():  501
#   times shape:  (501,)
#   states shape: (501, 3)  (N+1, system_size)
#   V(vout) final: 4.9661 V

# %%
v_out = states[:, rc.node_id_of("vout")]
v_theory = 5.0 * (1 - np.exp(-times / tau))

plt.figure(figsize=(10, 5))
plt.plot(times * 1e3, v_out, "r-", lw=2, label="V_out (simulated)")
plt.plot(times * 1e3, v_theory, "g--", lw=2, label="V_out (analytical)")
plt.axhline(5 * 0.632, color="gray", ls=":", alpha=0.7)
plt.axvline(tau * 1e3, color="gray", ls=":", alpha=0.7)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("RC step response - simulate() vs analytical")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

max_err = float(np.max(np.abs(v_out - v_theory)))
print(f"Max error vs analytical: {max_err * 1e3:.3f} mV ({max_err / 5.0 * 100:.3f} %)")
# Out:
# Max error vs analytical: 24.875 mV (0.498 %)

# %% [markdown]
# ## 5. Switching simulation with a PWM switch function
#
# For switched circuits, pass `switch_fn=` to `simulate(...)`. The helper
# `make_pwm_switch_fn(...)` builds a fixed-frequency / fixed-duty mask
# driver. (For closed-loop control, drive the switch from a
# `MixedDomainBlockChain` - see section 7.)

# %%
buck = p.CircuitBuilder()
buck.add_voltage_source("Vin", "vin", "gnd", 24.0)
buck.add_switch("S1", "vin", "sw", g_on=1e3, g_off=1e-9)
buck.add_diode("D1", "gnd", "sw", 1e3, 1e-9, V_th=0.3)
buck.add_inductor("L1", "sw", "vout", 220e-6)
buck.add_capacitor("C1", "vout", "gnd", 220e-6)
buck.add_resistor("Rload", "vout", "gnd", 8.0)

fsw = 100e3
DT = (1 / fsw) / 50
sw_fn = p.make_pwm_switch_fn(frequency=fsw, duty=0.5,
                             switch_idx=buck.switch_index_of("S1"),
                             num_switches=buck.graph.num_switches)

res_buck = p.simulate(buck, t_end=3e-3, dt=DT, switch_fn=sw_fn)
vout = np.array(res_buck.states)[:, buck.node_id_of("vout")]
print(f"Buck @ D=0.5, Vin=24 V -> V_out (steady) = "
      f"{np.mean(vout[int(0.8 * len(vout)):]):.2f} V (ideal ~ 12 V)")
# Out:
# Buck @ D=0.5, Vin=24 V -> V_out (steady) = 12.55 V (ideal ~ 12 V)

# %% [markdown]
# ## 6. Frequency-domain and steady-state analyses
#
# Beyond `simulate`, v2 ships a family of free-function analyses, each
# taking the builder as the first argument:
#
# | Function | Purpose |
# | --- | --- |
# | `run_ac_sweep(b, freqs=, excite_fn=, output_idx=)` | small-signal AC transfer function |
# | `run_fra(b, frequencies=, ...)` | frequency-response analysis (injection + measurements) |
# | `run_periodic_shooting(b, t_period=, dt=)` | converge directly to periodic steady state |
# | `run_harmonic_balance(b, period=, dt=)` | harmonic spectrum + THD |
# | `run_parameter_sweep(...)` / `monte_carlo(...)` | design-space exploration |
#
# Below we introspect the signatures (running a full AC sweep needs a
# plant-specific excitation, covered in the dedicated analysis notebooks).

# %%
import inspect

analyses = ["run_ac_sweep", "run_fra", "run_periodic_shooting",
            "run_harmonic_balance", "run_parameter_sweep", "monte_carlo"]
print("Available frequency / steady-state analyses:")
for name in analyses:
    fn = getattr(p, name, None)
    if fn is None:
        print(f"  p.{name}: (not exported)")
        continue
    try:
        sig = str(inspect.signature(fn))
        # Keep the first line short for display.
        sig = sig if len(sig) < 90 else sig[:87] + "...)"
    except (TypeError, ValueError):
        sig = "(...)"
    print(f"  p.{name}{sig}")
# Out:
# Available frequency / steady-state analyses:
#   p.run_ac_sweep(builder, *, freqs: 'Sequence[float]', excite_fn: 'Callable[[float, float, float], list...)
#   p.run_fra: (not exported)
#   p.run_periodic_shooting: (not exported)
#   p.run_harmonic_balance: (not exported)
#   p.run_parameter_sweep: (not exported)
#   p.monte_carlo(builder_factory: 'Callable[..., Any]', *, distributions: 'Dict[str, Callable[..., floa...)

# %% [markdown]
# ## 7. Control blocks - `MixedDomainBlockChain`
#
# v2 replaces v1's `SignalEvaluator` + closures with a composable chain of
# control blocks (`PIController`, `PwmGenerator`, `FirstOrderLowPass`, ...).
# The chain compiles to C++ so the controller runs at full kernel rate.
#
# Blocks read inputs from constants, **node names**, other blocks
# (`"channel:<name>"`), `"time"`, or `"dt"`; they write to named channels.

# %%
ctrl_blocks = [
    "PIController", "PIDController", "FirstOrderLowPass", "PwmGenerator",
    "Comparator", "Gain", "Sum", "Subtract", "Integrator", "Differentiator",
    "Limiter", "RateLimiter", "SampleHold", "DelayBlock",
    "MovingAverageFilter", "LookupTable1D", "TransferFunction", "MathBlock",
    "StateMachine", "SignalMux", "SignalDemux", "OpAmp",
    "ClarkeTransform", "ParkTransform", "SpaceVectorModulator", "PLL",
]
print("Control / signal-flow blocks available on the chain:")
for name in ctrl_blocks:
    print(f"  p.{name:<22} ({'OK' if hasattr(p, name) else 'MISSING'})")
# Out:
# Control / signal-flow blocks available on the chain:
#   p.PIController           (OK)
#   p.PIDController          (OK)
#   p.FirstOrderLowPass      (OK)
#   p.PwmGenerator           (OK)
#   p.Comparator             (OK)
#   p.Gain                   (OK)
#   p.Sum                    (OK)
#   p.Subtract               (OK)
#   p.Integrator             (OK)
#   p.Differentiator         (OK)
#   p.Limiter                (OK)
#   p.RateLimiter            (OK)
#   p.SampleHold             (OK)
#   p.DelayBlock             (OK)
#   p.MovingAverageFilter    (OK)
#   p.LookupTable1D          (OK)
#   p.TransferFunction       (OK)
#   p.MathBlock              (OK)
#   p.StateMachine           (OK)
#   p.SignalMux              (OK)
#   p.SignalDemux            (OK)
#   p.OpAmp                  (OK)
#   p.ClarkeTransform        (OK)
#   p.ParkTransform          (OK)
#   p.SpaceVectorModulator   (OK)
#   p.PLL                    (OK)

# %%
# Closed-loop buck: software PI -> PWM -> switch, all in one chain.
cl = p.CircuitBuilder()
cl.add_voltage_source("Vin", "vin", "gnd", 24.0)
cl.add_mosfet_with_body_diode("Q1", "vin", "sw", R_on=20e-3, R_off=1e8, V_F=0.7)
cl.add_diode("D1", "gnd", "sw", 1e3, 1e-9, V_th=0.3)
cl.add_inductor("L1", "sw", "vout", 220e-6)
cl.add_capacitor("C1", "vout", "gnd", 220e-6)
cl.add_resistor("Rload", "vout", "gnd", 8.0)

DT = (1 / fsw) / 50
chain = p.MixedDomainBlockChain()
chain.add("lpf", p.FirstOrderLowPass(tau=200e-6),
          inputs=dict(input_value="vout", dt="dt"), output="v_filt")
chain.add("pi", p.PIController(Kp=0.02, Ki=150.0, output_min=0.05, output_max=0.95),
          inputs=dict(setpoint=12.0, measured="channel:v_filt", dt="dt"),
          output="duty")
chain.add("pwm", p.PwmGenerator(frequency=fsw),
          inputs=dict(duty="channel:duty", t="time"), output="gate")

# make_step_observer compiles the chain to C++ first; register the channel
# recording AFTER that so the C++ backend captures it.
obs = chain.make_step_observer(cl, dt=DT)
chain.record_channel("duty")
sw = chain.make_pwm_switch_fn("gate", num_switches=cl.graph.num_switches,
                              switch_idx=cl.switch_index_of("Q1"))
res_cl = p.simulate(cl, t_end=6e-3, dt=DT, switch_fn=sw, step_observer=obs)

vout_cl = np.array(res_cl.states)[:, cl.node_id_of("vout")]
print(f"Closed-loop buck settled to {np.mean(vout_cl[int(0.8 * len(vout_cl)):]):.2f} V "
      f"(setpoint 12 V); final duty (chain) = {chain.get('duty'):.3f}")
# Out:
# Closed-loop buck settled to 8.88 V (setpoint 12 V); final duty (chain) = 0.600

# %% [markdown]
# ## 8. Analytical references for validation
#
# v2 keeps lightweight analytical references handy for cross-checking
# sims. Below: an exact underdamped RLC step response in pure NumPy,
# the same way `08_validation.ipynb` checks the kernel.

# %%
# Series RLC, underdamped, step from 0 to 10 V across the capacitor.
R, L, C, V = 10.0, 1e-3, 1e-6, 10.0
omega0 = 1.0 / np.sqrt(L * C)
zeta = (R / 2.0) * np.sqrt(C / L)
print(f"omega_0 = {omega0:.1f} rad/s,  zeta = {zeta:.3f} "
      f"({'under' if zeta < 1 else 'over'}damped)")

t = np.linspace(0, 0.5e-3, 500)
wd = omega0 * np.sqrt(1 - zeta**2)
vc = V * (1 - np.exp(-zeta * omega0 * t) *
          (np.cos(wd * t) + (zeta * omega0 / wd) * np.sin(wd * t)))

plt.figure(figsize=(10, 4))
plt.plot(t * 1e3, vc, "b-", lw=2)
plt.axhline(V, color="gray", ls="--", alpha=0.6)
plt.xlabel("Time (ms)")
plt.ylabel("V_C (V)")
plt.title("Underdamped RLC step response (analytical reference)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# omega_0 = 31622.8 rad/s,  zeta = 0.158 (underdamped)

# %% [markdown]
# ## Summary - v2 API at a glance
#
# ```python
# import pulsim as p
#
# # Build (string node names; 'gnd' is ground)
# b = p.CircuitBuilder()
# b.add_voltage_source("V1", "in", "gnd", 12.0)
# b.add_resistor("R1", "in", "out", 1e3)
# b.add_capacitor("C1", "out", "gnd", 1e-6)
#
# # DC operating point
# dc = p.compute_dc_op(b)
# v = dc[b.node_id_of("out")]
#
# # Transient
# res = p.simulate(b, t_end=5e-3, dt=1e-5)
# states = res.states                       # (N+1, system_size)
# v = np.array(states)[:, b.node_id_of("out")]
#
# # Switching
# sw = p.make_pwm_switch_fn(frequency=100e3, duty=0.5,
#                           switch_idx=0, num_switches=b.graph.num_switches)
# res = p.simulate(b, t_end=3e-3, dt=2e-7, switch_fn=sw)
#
# # Control / closed loop
# chain = p.MixedDomainBlockChain()
# chain.add("pi", p.PIController(Kp=.02, Ki=150, output_min=.05, output_max=.95),
#           inputs=dict(setpoint=12.0, measured="out", dt="dt"), output="duty")
# chain.add("pwm", p.PwmGenerator(frequency=100e3),
#           inputs=dict(duty="channel:duty", t="time"), output="gate")
# obs = chain.make_step_observer(b, dt=2e-7)
# sw  = chain.make_pwm_switch_fn("gate", num_switches=b.graph.num_switches, switch_idx=0)
# res = p.simulate(b, t_end=3e-3, dt=2e-7, switch_fn=sw, step_observer=obs)
#
# # Other analyses
# p.run_ac_sweep(b, freqs=..., excite_fn=..., output_idx=...)
# p.run_fra(b, frequencies=..., ...)
# p.run_periodic_shooting(b, t_period=..., dt=...)
# p.run_harmonic_balance(b, period=..., dt=...)
# ```
#
# See `docs/migration-from-v1.md` for the complete v1 -> v2 device and
# analysis mapping.
