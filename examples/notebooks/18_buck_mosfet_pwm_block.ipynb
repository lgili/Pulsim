# %% [markdown]
# # 18 - Buck com MOSFET e bloco PWM
#
# Exemplo objetivo de um buck com:
#
# - chave **MOSFET** (com diodo de corpo) no estagio de potencia;
# - diodo de roda-livre;
# - bloco **`PwmGenerator`** numa `MixedDomainBlockChain` gerando o gate.
#
# > **API v2 (migration-from-v1.md secao 5 e 8).** O v1 rodava periodo-a-
# > periodo: um `pwm_generator` virtual calculava o duty e
# > `circuit.set_pwm_duty("Vgate", duty)` reprogramava uma fonte PWM
# > eletrica do gate a cada `run_transient`. O v2 monta o PWM numa
# > `MixedDomainBlockChain` (`PwmGenerator`) que dirige diretamente a
# > chave do MOSFET via `chain.make_pwm_switch_fn`, e roda **uma unica**
# > `p.simulate(...)` (sem laco Python por periodo, ~10x mais rapido).
# >
# > O duty muda em degrau (0.26 -> 0.48) a meio da simulacao: o comando de
# > duty e injetado num no `d_cmd` por um `step_observer` que compoe o
# > observer da chain — mostrando como variar um setpoint ao longo do
# > tempo. Para malha fechada, troque o degrau por um `PIController`
# > (veja `14_api_reference.ipynb`).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pulsim as p

print(f"Pulsim version: {p.__version__}")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# ...

# %%
def create_buck_mosfet(Vin=24.0, L=220e-6, C=220e-6, Rload=8.0):
    """v2 buck power stage: MOSFET (com diodo de corpo) + diodo de roda-livre.

    Inclui um no auxiliar `d_cmd` (alto-ohmico para gnd) usado como
    portador do comando de duty lido pela chain.
    """
    b = p.CircuitBuilder()
    b.add_voltage_source("Vin", "vin", "gnd", Vin)
    b.add_mosfet_with_body_diode("M1", "vin", "sw", R_on=30e-3, R_off=1e8, V_F=0.7)
    b.add_diode("D1", "gnd", "sw", 350.0, 1e-9, V_th=0.3)
    b.add_inductor("L1", "sw", "out", L)
    b.add_capacitor("C1", "out", "gnd", C)
    b.add_resistor("Rload", "out", "gnd", Rload)
    b.add_resistor("R_dcmd", "d_cmd", "gnd", 1e9)  # carrier do comando de duty
    return b


def build_pwm_chain(b, fsw, dt):
    """PwmGenerator numa MixedDomainBlockChain dirigindo a chave M1.

    O duty vem do no `d_cmd` (clampeado no observer); o PWM gera o gate;
    `make_pwm_switch_fn` converte o canal `gate` na mascara da chave.
    """
    chain = p.MixedDomainBlockChain()
    chain.add("pwm", p.PwmGenerator(frequency=fsw),
              inputs=dict(duty="d_cmd", t="time"), output="gate")
    observer = chain.make_step_observer(b, dt=dt)
    switch_fn = chain.make_pwm_switch_fn(
        "gate", num_switches=b.graph.num_switches,
        switch_idx=b.switch_index_of("M1"))
    return chain, observer, switch_fn

# %%
Vin = 24.0
fsw = 100e3
Tsw = 1.0 / fsw
L = 220e-6
C = 220e-6
Rload = 8.0

duty_low = 0.26
duty_high = 0.48
step_period = 180          # periodo em que o duty da o degrau
periods = 450
dt = Tsw / 80.0            # 80 passos por periodo de comutacao
t_step = step_period * Tsw

b = create_buck_mosfet(Vin=Vin, L=L, C=C, Rload=Rload)
chain, chain_obs, switch_fn = build_pwm_chain(b, fsw, dt)

# Comando de duty em degrau, injetado no no `d_cmd` a cada passo. O
# observer compoe o do chain: clampa o duty (como o duty_min/max do v1)
# e escreve no estado ANTES do chain ler o no.
DUTY_MIN, DUTY_MAX = 0.05, 0.90
dcmd_idx = b.node_id_of("d_cmd")

def observer(t, x):
    d = duty_low if t < t_step else duty_high
    x[dcmd_idx] = max(DUTY_MIN, min(DUTY_MAX, d))
    chain_obs(t, x)

res = p.simulate(b, t_end=periods * Tsw, dt=dt,
                 switch_fn=switch_fn, step_observer=observer)

times = np.array(res.times)
states = np.array(res.states)
v_out = states[:, b.node_id_of("out")]
v_sw = states[:, b.node_id_of("sw")]

# Media por periodo de comutacao (equivalente ao laco periodo-a-periodo do v1).
time_ms, vout_avg, vsw_avg, duty_cmd_hist = [], [], [], []
for k in range(periods):
    t0, t1 = k * Tsw, (k + 1) * Tsw
    sel = (times >= t0) & (times < t1)
    if not np.any(sel):
        continue
    time_ms.append(t1 * 1e3)
    vout_avg.append(float(np.mean(v_out[sel])))
    vsw_avg.append(float(np.mean(v_sw[sel])))
    duty_cmd_hist.append(duty_low if t0 < t_step else duty_high)

time_ms = np.array(time_ms)
vout_avg = np.array(vout_avg)
vsw_avg = np.array(vsw_avg)
duty_cmd_hist = np.array(duty_cmd_hist)

print("Simulacao concluida (uma unica p.simulate).")
print(f"  passos totais: {res.num_steps()}")
print(f"  Vout medio (ultimos 50 periodos): {np.mean(vout_avg[-50:]):.3f} V")
print(f"  Duty final: {duty_cmd_hist[-1]:.3f}")
# Out:
# Running cmake --build & --install in /Users/lgili/Documents/01 - Codes/01 - Github/Pulsim/build/cp313-cp313-macosx_26_0_arm64
# Simulacao concluida (uma unica p.simulate).
#   passos totais: 36001
#   Vout medio (ultimos 50 periodos): 12.378 V
#   Duty final: 0.480

# %%
fig, ax = plt.subplots(3, 1, figsize=(11, 9), sharex=True)

ax[0].plot(time_ms, vout_avg, lw=2.0, color="#1f77b4", label="Vout medio/periodo")
ax[0].axvline(t_step * 1e3, ls="--", color="#666", label="degrau de duty")
ax[0].set_ylabel("Vout [V]")
ax[0].grid(alpha=0.25)
ax[0].legend(loc="best")

ax[1].plot(time_ms, duty_cmd_hist, lw=1.8, color="#d62728", label="Duty comando")
ax[1].axhline(0.05, ls=":", color="#aaa", lw=1.0)
ax[1].axhline(0.90, ls=":", color="#aaa", lw=1.0, label="clamp [0.05, 0.90]")
ax[1].set_ylabel("Duty")
ax[1].set_ylim(0.0, 1.0)
ax[1].grid(alpha=0.25)
ax[1].legend(loc="best")

ax[2].plot(time_ms, vsw_avg, lw=1.4, color="#9467bd", label="V(sw) medio/periodo")
ax[2].axvline(t_step * 1e3, ls="--", color="#666")
ax[2].set_ylabel("V(sw) [V]")
ax[2].set_xlabel("Tempo [ms]")
ax[2].grid(alpha=0.25)
ax[2].legend(loc="best")

plt.tight_layout()
plt.show()

# %%
n = len(vout_avg)
# Identifica o indice do degrau na grade de periodos efetiva.
step_idx = int(np.searchsorted(time_ms, t_step * 1e3))
pre = slice(max(0, step_idx - 60), step_idx)
post = slice(max(0, n - 60), n)

summary = {
    "Vout medio antes do degrau [V]": float(np.mean(vout_avg[pre])),
    "Vout medio depois do degrau [V]": float(np.mean(vout_avg[post])),
    "Duty antes": float(np.mean(duty_cmd_hist[pre])),
    "Duty depois": float(np.mean(duty_cmd_hist[post])),
}
summary
# Out:
# {'Vout medio antes do degrau [V]': 7.5498950473063475,
#  'Vout medio depois do degrau [V]': 12.341009782481953,
#  'Duty antes': 0.26,
#  'Duty depois': 0.48000000000000004}

# %% [markdown]
# ## Observacoes
#
# - O estagio de potencia usa **MOSFET com diodo de corpo** + diodo de
#   roda-livre; o gate vem de um **`PwmGenerator`** numa
#   `MixedDomainBlockChain`, que dirige a chave por
#   `chain.make_pwm_switch_fn`.
# - Tudo roda em **uma unica `p.simulate(...)`** — sem laco Python por
#   periodo. O degrau de duty (0.26 -> 0.48) e injetado no no `d_cmd` por
#   um `step_observer` que compoe o observer da chain.
# - O Vout medio acompanha `D * Vin` (menos quedas no MOSFET/diodo),
#   saltando de ~7 V para ~12 V no degrau.
# - Para **malha fechada**, troque o degrau de duty por um
#   `p.PIController` realimentado por `V(out)` (canal `channel:`), como em
#   `14_api_reference.ipynb` secao 7.
